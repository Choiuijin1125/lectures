# %%
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.layers import LSTM, Flatten, TimeDistributed, Conv1D, MaxPooling1D
from tensorflow.keras import Model, Sequential
import json

mpl.rcParams['figure.figsize'] = (8, 6)
mpl.rcParams['axes.grid'] = False

# %%
# !pip install -q tensorflow-gpu==2.0.0-rc1
# Out:
#      |████████████████████████████████| 380.5MB 74kB/s
#      |████████████████████████████████| 501kB 41.3MB/s
#      |████████████████████████████████| 4.3MB 29.7MB/s

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
tf.__version__
# Out:
# '2.0.0-rc1'

# %%
main_path = 'drive/My Drive/Colab Notebooks/competition'
train_df = pd.read_csv(os.path.join(main_path, 'processed_test_data.csv'))
train_df = train_df.fillna(method='ffill')

# %%
cols = train_df.columns.to_list()
cols = cols[1:]

# %%
tf.random.set_seed(13)

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %%
def datasets(data):
    dataset = train_df[[data]]
    dataset = dataset.dropna()
    dataset = dataset.values
    data_max = dataset.max(axis=0)
    data_min = dataset.min(axis=0)
    dataset = (dataset-data_min) / (data_max-data_min)
    return dataset

# %%
for i in range(140, 150):
    dataset = datasets(cols[i])
    TRAIN_SPLIT = len(dataset) - int(0.2 * len(dataset))
    BATCH_SIZE = 256
    BUFFER_SIZE = 10000
    past_history = 168
    future_target = 24
    STEP = 1

    n_features = 1
    n_seq = 2
    n_steps = 84

    x_train_multi, y_train_multi = multivariate_data(dataset, dataset, 0,
                                                       TRAIN_SPLIT, past_history,
                                                       future_target, STEP,
                                                       single_step=False)
    x_val_multi, y_val_multi = multivariate_data(dataset, dataset,
                                                   TRAIN_SPLIT, None, past_history,
                                                   future_target, STEP,
                                                   single_step=False)
    
    x_train_multi = x_train_multi.reshape((x_train_multi.shape[0], n_seq, n_steps, n_features))
    x_val_multi = x_val_multi.reshape((x_val_multi.shape[0], n_seq, n_steps, n_features))

    train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
    train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

    val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
    val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()
    checkpoint_path = "training_2_"+cols[i]
    end_point = "cp-{epoch:04d}.ckpt"
    checkpoint_dir = os.path.join(main_path, checkpoint_path, end_point)
    # 파일 이름에 에포크 번호를 포함시킵니다(`str.format` 포맷)
    
    
    # 체크포인트 콜백 만들기
    cp_callback = [tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                    patience=7),
                   
                   tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                     save_weights_only=True,
                                                     verbose=1, 
                                                     monitor='val_loss',
                                                     save_best_only=True)]


    multi_step_model = tf.keras.models.Sequential()
    multi_step_model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), input_shape=(None, n_steps, n_features)))
    multi_step_model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
    multi_step_model.add(TimeDistributed(Flatten()))
    
    multi_step_model.add(tf.keras.layers.LSTM(16,
                                              return_sequences=True,
                                              input_shape=x_train_multi.shape[-2:], activation='softsign'))
    multi_step_model.add(tf.keras.layers.LSTM(8, activation='relu'))
    multi_step_model.add(tf.keras.layers.Dense(24))

    multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')
    EVALUATION_INTERVAL = 200
    EPOCHS = 40

    multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                              steps_per_epoch=EVALUATION_INTERVAL,
                                              validation_data=val_data_multi,
                                              validation_steps=50,
                                              callbacks = cp_callback)


    
    with open(os.path.join(main_path, 'json', cols[i]+'.json'), 'w') as file:

        json.dump(multi_step_history.history, file)
# Out:
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.1543
# Epoch 00001: val_loss improved from inf to 0.11683, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X333/cp-0001.ckpt
# 200/200 [==============================] - 7s 37ms/step - loss: 0.1539 - val_loss: 0.1168
# Epoch 2/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.1255
# Epoch 00002: val_loss improved from 0.11683 to 0.11346, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X333/cp-0002.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1254 - val_loss: 0.1135
# Epoch 3/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.1180
# Epoch 00003: val_loss improved from 0.11346 to 0.11207, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X333/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1179 - val_loss: 0.1121
# Epoch 4/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.1148
# Epoch 00004: val_loss improved from 0.11207 to 0.11065, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X333/cp-0004.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1148 - val_loss: 0.1107
# Epoch 5/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.1132
# Epoch 00005: val_loss improved from 0.11065 to 0.11011, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X333/cp-0005.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1132 - val_loss: 0.1101
# Epoch 6/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.1120
# Epoch 00006: val_loss did not improve from 0.11011
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1120 - val_loss: 0.1107
# Epoch 7/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.1109
# Epoch 00007: val_loss improved from 0.11011 to 0.10957, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X333/cp-0007.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1109 - val_loss: 0.1096
# Epoch 8/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.1093
# Epoch 00008: val_loss improved from 0.10957 to 0.10889, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X333/cp-0008.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1093 - val_loss: 0.1089
# Epoch 9/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.1075
# Epoch 00009: val_loss improved from 0.10889 to 0.10751, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X333/cp-0009.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1075 - val_loss: 0.1075
# Epoch 10/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.1065
# Epoch 00010: val_loss did not improve from 0.10751
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1064 - val_loss: 0.1077
# Epoch 11/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.1055
# Epoch 00011: val_loss did not improve from 0.10751
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1055 - val_loss: 0.1081
# Epoch 12/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.1047
# Epoch 00012: val_loss did not improve from 0.10751
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1047 - val_loss: 0.1089
# Epoch 13/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.1041
# Epoch 00013: val_loss did not improve from 0.10751
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1041 - val_loss: 0.1084
# Epoch 14/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.1035
# Epoch 00014: val_loss did not improve from 0.10751
# 200/200 [==============================] - 4s 21ms/step - loss: 0.1035 - val_loss: 0.1089
# Epoch 15/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.1029
# Epoch 00015: val_loss did not improve from 0.10751
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1029 - val_loss: 0.1108
# Epoch 16/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.1023
# Epoch 00016: val_loss did not improve from 0.10751
# 200/200 [==============================] - 4s 22ms/step - loss: 0.1023 - val_loss: 0.1100
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0983
# Epoch 00001: val_loss improved from inf to 0.08788, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X337/cp-0001.ckpt
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0982 - val_loss: 0.0879
# Epoch 2/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0784
# Epoch 00002: val_loss improved from 0.08788 to 0.07383, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X337/cp-0002.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0784 - val_loss: 0.0738
# Epoch 3/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0728
# Epoch 00003: val_loss improved from 0.07383 to 0.06739, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X337/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0728 - val_loss: 0.0674
# Epoch 4/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0704
# Epoch 00004: val_loss did not improve from 0.06739
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0704 - val_loss: 0.0674
# Epoch 5/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0691
# Epoch 00005: val_loss improved from 0.06739 to 0.06667, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X337/cp-0005.ckpt
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0691 - val_loss: 0.0667
# Epoch 6/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0682
# Epoch 00006: val_loss improved from 0.06667 to 0.06567, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X337/cp-0006.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0682 - val_loss: 0.0657
# Epoch 7/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0675
# Epoch 00007: val_loss improved from 0.06567 to 0.06510, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X337/cp-0007.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0675 - val_loss: 0.0651
# Epoch 8/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0669
# Epoch 00008: val_loss did not improve from 0.06510
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0669 - val_loss: 0.0661
# Epoch 9/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0663
# Epoch 00009: val_loss did not improve from 0.06510
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0663 - val_loss: 0.0657
# Epoch 10/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0658
# Epoch 00010: val_loss did not improve from 0.06510
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0658 - val_loss: 0.0665
# Epoch 11/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0653
# Epoch 00011: val_loss improved from 0.06510 to 0.06508, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X337/cp-0011.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0653 - val_loss: 0.0651
# Epoch 12/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0649
# Epoch 00012: val_loss did not improve from 0.06508
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0649 - val_loss: 0.0653
# Epoch 13/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0644
# Epoch 00013: val_loss did not improve from 0.06508
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0644 - val_loss: 0.0655
# Epoch 14/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0641
# Epoch 00014: val_loss did not improve from 0.06508
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0641 - val_loss: 0.0654
# Epoch 15/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0636
# Epoch 00015: val_loss did not improve from 0.06508
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0636 - val_loss: 0.0662
# Epoch 16/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0633
# Epoch 00016: val_loss did not improve from 0.06508
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0633 - val_loss: 0.0664
# Epoch 17/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0630
# Epoch 00017: val_loss did not improve from 0.06508
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0630 - val_loss: 0.0669
# Epoch 18/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0627
# Epoch 00018: val_loss did not improve from 0.06508
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0627 - val_loss: 0.0672
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0745
# Epoch 00001: val_loss improved from inf to 0.07242, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X341/cp-0001.ckpt
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0744 - val_loss: 0.0724
# Epoch 2/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0692
# Epoch 00002: val_loss improved from 0.07242 to 0.06997, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X341/cp-0002.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0692 - val_loss: 0.0700
# Epoch 3/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0669
# Epoch 00003: val_loss improved from 0.06997 to 0.06840, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X341/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0669 - val_loss: 0.0684
# Epoch 4/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0650
# Epoch 00004: val_loss improved from 0.06840 to 0.06820, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X341/cp-0004.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0650 - val_loss: 0.0682
# Epoch 5/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0634
# Epoch 00005: val_loss improved from 0.06820 to 0.06789, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X341/cp-0005.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0634 - val_loss: 0.0679
# Epoch 6/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0625
# Epoch 00006: val_loss improved from 0.06789 to 0.06676, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X341/cp-0006.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0625 - val_loss: 0.0668
# Epoch 7/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0614
# Epoch 00007: val_loss did not improve from 0.06676
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0614 - val_loss: 0.0671
# Epoch 8/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0605
# Epoch 00008: val_loss improved from 0.06676 to 0.06653, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X341/cp-0008.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0605 - val_loss: 0.0665
# Epoch 9/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0596
# Epoch 00009: val_loss did not improve from 0.06653
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0596 - val_loss: 0.0666
# Epoch 10/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0588
# Epoch 00010: val_loss did not improve from 0.06653
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0588 - val_loss: 0.0680
# Epoch 11/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0581
# Epoch 00011: val_loss did not improve from 0.06653
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0581 - val_loss: 0.0679
# Epoch 12/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0573
# Epoch 00012: val_loss did not improve from 0.06653
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0573 - val_loss: 0.0674
# Epoch 13/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0568
# Epoch 00013: val_loss did not improve from 0.06653
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0568 - val_loss: 0.0668
# Epoch 14/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0562
# Epoch 00014: val_loss did not improve from 0.06653
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0562 - val_loss: 0.0668
# Epoch 15/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0557
# Epoch 00015: val_loss did not improve from 0.06653
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0557 - val_loss: 0.0687
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0513
# Epoch 00001: val_loss improved from inf to 0.04167, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0001.ckpt
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0513 - val_loss: 0.0417
# Epoch 2/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0434
# Epoch 00002: val_loss improved from 0.04167 to 0.04024, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0002.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0434 - val_loss: 0.0402
# Epoch 3/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0424
# Epoch 00003: val_loss improved from 0.04024 to 0.03934, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0424 - val_loss: 0.0393
# Epoch 4/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0417
# Epoch 00004: val_loss improved from 0.03934 to 0.03863, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0004.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0417 - val_loss: 0.0386
# Epoch 5/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0412
# Epoch 00005: val_loss improved from 0.03863 to 0.03827, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0005.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0411 - val_loss: 0.0383
# Epoch 6/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0407
# Epoch 00006: val_loss did not improve from 0.03827
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0407 - val_loss: 0.0384
# Epoch 7/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0403
# Epoch 00007: val_loss improved from 0.03827 to 0.03761, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0007.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0403 - val_loss: 0.0376
# Epoch 8/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0399
# Epoch 00008: val_loss did not improve from 0.03761
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0399 - val_loss: 0.0380
# Epoch 9/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0395
# Epoch 00009: val_loss did not improve from 0.03761
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0395 - val_loss: 0.0379
# Epoch 10/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0391
# Epoch 00010: val_loss improved from 0.03761 to 0.03680, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0010.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0391 - val_loss: 0.0368
# Epoch 11/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0388
# Epoch 00011: val_loss did not improve from 0.03680
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0388 - val_loss: 0.0370
# Epoch 12/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0385
# Epoch 00012: val_loss improved from 0.03680 to 0.03633, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0012.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0385 - val_loss: 0.0363
# Epoch 13/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0382
# Epoch 00013: val_loss did not improve from 0.03633
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0382 - val_loss: 0.0364
# Epoch 14/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0380
# Epoch 00014: val_loss did not improve from 0.03633
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0380 - val_loss: 0.0369
# Epoch 15/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00015: val_loss improved from 0.03633 to 0.03584, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0015.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0377 - val_loss: 0.0358
# Epoch 16/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0376
# Epoch 00016: val_loss improved from 0.03584 to 0.03583, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0016.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0376 - val_loss: 0.0358
# Epoch 17/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0374
# Epoch 00017: val_loss improved from 0.03583 to 0.03562, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0017.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0374 - val_loss: 0.0356
# Epoch 18/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0373
# Epoch 00018: val_loss improved from 0.03562 to 0.03558, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X347/cp-0018.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0373 - val_loss: 0.0356
# Epoch 19/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0372
# Epoch 00019: val_loss did not improve from 0.03558
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0372 - val_loss: 0.0360
# Epoch 20/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0370
# Epoch 00020: val_loss did not improve from 0.03558
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0370 - val_loss: 0.0358
# Epoch 21/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0369
# Epoch 00021: val_loss did not improve from 0.03558
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0369 - val_loss: 0.0360
# Epoch 22/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0368
# Epoch 00022: val_loss did not improve from 0.03558
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0368 - val_loss: 0.0365
# Epoch 23/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0367
# Epoch 00023: val_loss did not improve from 0.03558
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0367 - val_loss: 0.0359
# Epoch 24/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0367
# Epoch 00024: val_loss did not improve from 0.03558
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0367 - val_loss: 0.0358
# Epoch 25/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0366
# Epoch 00025: val_loss did not improve from 0.03558
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0366 - val_loss: 0.0357
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0584
# Epoch 00001: val_loss improved from inf to 0.04703, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X349/cp-0001.ckpt
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0583 - val_loss: 0.0470
# Epoch 2/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0519
# Epoch 00002: val_loss did not improve from 0.04703
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0518 - val_loss: 0.0471
# Epoch 3/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0513
# Epoch 00003: val_loss improved from 0.04703 to 0.04611, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X349/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0513 - val_loss: 0.0461
# Epoch 4/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0508
# Epoch 00004: val_loss did not improve from 0.04611
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0508 - val_loss: 0.0465
# Epoch 5/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0503
# Epoch 00005: val_loss improved from 0.04611 to 0.04605, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X349/cp-0005.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0503 - val_loss: 0.0461
# Epoch 6/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0498
# Epoch 00006: val_loss improved from 0.04605 to 0.04548, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X349/cp-0006.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0498 - val_loss: 0.0455
# Epoch 7/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0493
# Epoch 00007: val_loss improved from 0.04548 to 0.04455, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X349/cp-0007.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0493 - val_loss: 0.0446
# Epoch 8/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0490
# Epoch 00008: val_loss did not improve from 0.04455
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0490 - val_loss: 0.0451
# Epoch 9/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0486
# Epoch 00009: val_loss improved from 0.04455 to 0.04421, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X349/cp-0009.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0486 - val_loss: 0.0442
# Epoch 10/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0484
# Epoch 00010: val_loss did not improve from 0.04421
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0484 - val_loss: 0.0468
# Epoch 11/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0481
# Epoch 00011: val_loss did not improve from 0.04421
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0481 - val_loss: 0.0447
# Epoch 12/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0480
# Epoch 00012: val_loss did not improve from 0.04421
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0480 - val_loss: 0.0443
# Epoch 13/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0476
# Epoch 00013: val_loss improved from 0.04421 to 0.04359, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X349/cp-0013.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0476 - val_loss: 0.0436
# Epoch 14/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0476
# Epoch 00014: val_loss did not improve from 0.04359
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0476 - val_loss: 0.0446
# Epoch 15/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0474
# Epoch 00015: val_loss did not improve from 0.04359
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0474 - val_loss: 0.0437
# Epoch 16/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0472
# Epoch 00016: val_loss improved from 0.04359 to 0.04356, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X349/cp-0016.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0472 - val_loss: 0.0436
# Epoch 17/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0470
# Epoch 00017: val_loss did not improve from 0.04356
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0470 - val_loss: 0.0445
# Epoch 18/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0468
# Epoch 00018: val_loss did not improve from 0.04356
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0469 - val_loss: 0.0437
# Epoch 19/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0466
# Epoch 00019: val_loss did not improve from 0.04356
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0466 - val_loss: 0.0436
# Epoch 20/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0464
# Epoch 00020: val_loss improved from 0.04356 to 0.04325, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X349/cp-0020.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0464 - val_loss: 0.0432
# Epoch 21/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0463
# Epoch 00021: val_loss did not improve from 0.04325
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0463 - val_loss: 0.0433
# Epoch 22/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0462
# Epoch 00022: val_loss did not improve from 0.04325
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0462 - val_loss: 0.0434
# Epoch 23/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0459
# Epoch 00023: val_loss did not improve from 0.04325
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0459 - val_loss: 0.0434
# Epoch 24/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0459
# Epoch 00024: val_loss did not improve from 0.04325
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0459 - val_loss: 0.0443
# Epoch 25/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0457
# Epoch 00025: val_loss did not improve from 0.04325
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0457 - val_loss: 0.0435
# Epoch 26/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0455
# Epoch 00026: val_loss did not improve from 0.04325
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0456 - val_loss: 0.0434
# Epoch 27/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0454
# Epoch 00027: val_loss did not improve from 0.04325
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0454 - val_loss: 0.0447
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0662
# Epoch 00001: val_loss improved from inf to 0.04024, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0001.ckpt
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0661 - val_loss: 0.0402
# Epoch 2/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0447
# Epoch 00002: val_loss improved from 0.04024 to 0.03977, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0002.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0447 - val_loss: 0.0398
# Epoch 3/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0441
# Epoch 00003: val_loss improved from 0.03977 to 0.03840, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0441 - val_loss: 0.0384
# Epoch 4/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0431
# Epoch 00004: val_loss improved from 0.03840 to 0.03722, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0004.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0431 - val_loss: 0.0372
# Epoch 5/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0420
# Epoch 00005: val_loss improved from 0.03722 to 0.03560, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0005.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0420 - val_loss: 0.0356
# Epoch 6/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0409
# Epoch 00006: val_loss improved from 0.03560 to 0.03367, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0006.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0409 - val_loss: 0.0337
# Epoch 7/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0401
# Epoch 00007: val_loss improved from 0.03367 to 0.03288, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0007.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0401 - val_loss: 0.0329
# Epoch 8/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0394
# Epoch 00008: val_loss improved from 0.03288 to 0.03252, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0008.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0394 - val_loss: 0.0325
# Epoch 9/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0389
# Epoch 00009: val_loss improved from 0.03252 to 0.03213, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0009.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0389 - val_loss: 0.0321
# Epoch 10/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0387
# Epoch 00010: val_loss did not improve from 0.03213
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0387 - val_loss: 0.0327
# Epoch 11/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0384
# Epoch 00011: val_loss improved from 0.03213 to 0.03204, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0011.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0384 - val_loss: 0.0320
# Epoch 12/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0383
# Epoch 00012: val_loss improved from 0.03204 to 0.03200, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0012.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0383 - val_loss: 0.0320
# Epoch 13/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0381
# Epoch 00013: val_loss improved from 0.03200 to 0.03192, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0013.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0381 - val_loss: 0.0319
# Epoch 14/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0379
# Epoch 00014: val_loss did not improve from 0.03192
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0379 - val_loss: 0.0320
# Epoch 15/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0379
# Epoch 00015: val_loss improved from 0.03192 to 0.03189, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0015.ckpt
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0379 - val_loss: 0.0319
# Epoch 16/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0377
# Epoch 00016: val_loss did not improve from 0.03189
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0377 - val_loss: 0.0319
# Epoch 17/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0376
# Epoch 00017: val_loss did not improve from 0.03189
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0376 - val_loss: 0.0319
# Epoch 18/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0375
# Epoch 00018: val_loss did not improve from 0.03189
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0375 - val_loss: 0.0320
# Epoch 19/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0374
# Epoch 00019: val_loss improved from 0.03189 to 0.03185, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X350/cp-0019.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0374 - val_loss: 0.0319
# Epoch 20/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0373
# Epoch 00020: val_loss did not improve from 0.03185
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0373 - val_loss: 0.0324
# Epoch 21/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0372
# Epoch 00021: val_loss did not improve from 0.03185
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0372 - val_loss: 0.0323
# Epoch 22/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0371
# Epoch 00022: val_loss did not improve from 0.03185
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0371 - val_loss: 0.0320
# Epoch 23/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0370
# Epoch 00023: val_loss did not improve from 0.03185
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0370 - val_loss: 0.0326
# Epoch 24/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0369
# Epoch 00024: val_loss did not improve from 0.03185
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0369 - val_loss: 0.0321
# Epoch 25/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0368
# Epoch 00025: val_loss did not improve from 0.03185
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0368 - val_loss: 0.0322
# Epoch 26/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0367
# Epoch 00026: val_loss did not improve from 0.03185
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0367 - val_loss: 0.0320
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0574
# Epoch 00001: val_loss improved from inf to 0.05614, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0001.ckpt
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0573 - val_loss: 0.0561
# Epoch 2/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0485
# Epoch 00002: val_loss improved from 0.05614 to 0.05565, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0002.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0485 - val_loss: 0.0556
# Epoch 3/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0470
# Epoch 00003: val_loss improved from 0.05565 to 0.05438, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0470 - val_loss: 0.0544
# Epoch 4/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0458
# Epoch 00004: val_loss improved from 0.05438 to 0.05329, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0004.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0458 - val_loss: 0.0533
# Epoch 5/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0448
# Epoch 00005: val_loss improved from 0.05329 to 0.05208, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0005.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0448 - val_loss: 0.0521
# Epoch 6/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0440
# Epoch 00006: val_loss improved from 0.05208 to 0.05064, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0006.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0440 - val_loss: 0.0506
# Epoch 7/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0432
# Epoch 00007: val_loss improved from 0.05064 to 0.04966, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0007.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0432 - val_loss: 0.0497
# Epoch 8/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0426
# Epoch 00008: val_loss improved from 0.04966 to 0.04786, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0008.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0425 - val_loss: 0.0479
# Epoch 9/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0419
# Epoch 00009: val_loss improved from 0.04786 to 0.04709, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0009.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0419 - val_loss: 0.0471
# Epoch 10/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0415
# Epoch 00010: val_loss did not improve from 0.04709
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0415 - val_loss: 0.0473
# Epoch 11/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0412
# Epoch 00011: val_loss did not improve from 0.04709
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0412 - val_loss: 0.0472
# Epoch 12/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0409
# Epoch 00012: val_loss improved from 0.04709 to 0.04677, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0012.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0409 - val_loss: 0.0468
# Epoch 13/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0407
# Epoch 00013: val_loss did not improve from 0.04677
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0407 - val_loss: 0.0473
# Epoch 14/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0405
# Epoch 00014: val_loss improved from 0.04677 to 0.04665, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0014.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0405 - val_loss: 0.0467
# Epoch 15/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0403
# Epoch 00015: val_loss improved from 0.04665 to 0.04654, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X352/cp-0015.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0403 - val_loss: 0.0465
# Epoch 16/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0401
# Epoch 00016: val_loss did not improve from 0.04654
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0401 - val_loss: 0.0470
# Epoch 17/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0399
# Epoch 00017: val_loss did not improve from 0.04654
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0399 - val_loss: 0.0470
# Epoch 18/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0398
# Epoch 00018: val_loss did not improve from 0.04654
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0398 - val_loss: 0.0466
# Epoch 19/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0396
# Epoch 00019: val_loss did not improve from 0.04654
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0396 - val_loss: 0.0468
# Epoch 20/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0395
# Epoch 00020: val_loss did not improve from 0.04654
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0395 - val_loss: 0.0476
# Epoch 21/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0392
# Epoch 00021: val_loss did not improve from 0.04654
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0392 - val_loss: 0.0477
# Epoch 22/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0392
# Epoch 00022: val_loss did not improve from 0.04654
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0392 - val_loss: 0.0472
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0427
# Epoch 00001: val_loss improved from inf to 0.02453, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X353/cp-0001.ckpt
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0426 - val_loss: 0.0245
# Epoch 2/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0334
# Epoch 00002: val_loss improved from 0.02453 to 0.02374, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X353/cp-0002.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0334 - val_loss: 0.0237
# Epoch 3/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0325
# Epoch 00003: val_loss improved from 0.02374 to 0.02333, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X353/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0326 - val_loss: 0.0233
# Epoch 4/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0321
# Epoch 00004: val_loss improved from 0.02333 to 0.02315, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X353/cp-0004.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0321 - val_loss: 0.0231
# Epoch 5/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0319
# Epoch 00005: val_loss did not improve from 0.02315
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0319 - val_loss: 0.0235
# Epoch 6/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0316
# Epoch 00006: val_loss did not improve from 0.02315
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0316 - val_loss: 0.0236
# Epoch 7/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0315
# Epoch 00007: val_loss improved from 0.02315 to 0.02310, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X353/cp-0007.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0315 - val_loss: 0.0231
# Epoch 8/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0314
# Epoch 00008: val_loss improved from 0.02310 to 0.02304, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X353/cp-0008.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0314 - val_loss: 0.0230
# Epoch 9/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0313
# Epoch 00009: val_loss did not improve from 0.02304
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0313 - val_loss: 0.0232
# Epoch 10/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0312
# Epoch 00010: val_loss improved from 0.02304 to 0.02303, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X353/cp-0010.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0312 - val_loss: 0.0230
# Epoch 11/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0311
# Epoch 00011: val_loss did not improve from 0.02303
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0311 - val_loss: 0.0230
# Epoch 12/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0310
# Epoch 00012: val_loss did not improve from 0.02303
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0310 - val_loss: 0.0231
# Epoch 13/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0310
# Epoch 00013: val_loss did not improve from 0.02303
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0310 - val_loss: 0.0232
# Epoch 14/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0309
# Epoch 00014: val_loss did not improve from 0.02303
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0309 - val_loss: 0.0233
# Epoch 15/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0307
# Epoch 00015: val_loss did not improve from 0.02303
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0307 - val_loss: 0.0231
# Epoch 16/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0307
# Epoch 00016: val_loss improved from 0.02303 to 0.02302, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X353/cp-0016.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0307 - val_loss: 0.0230
# Epoch 17/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0306
# Epoch 00017: val_loss improved from 0.02302 to 0.02299, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X353/cp-0017.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0306 - val_loss: 0.0230
# Epoch 18/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0304
# Epoch 00018: val_loss did not improve from 0.02299
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0304 - val_loss: 0.0231
# Epoch 19/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0304
# Epoch 00019: val_loss did not improve from 0.02299
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0304 - val_loss: 0.0231
# Epoch 20/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0303
# Epoch 00020: val_loss did not improve from 0.02299
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0303 - val_loss: 0.0231
# Epoch 21/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0302
# Epoch 00021: val_loss did not improve from 0.02299
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0302 - val_loss: 0.0232
# Epoch 22/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0302
# Epoch 00022: val_loss did not improve from 0.02299
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0302 - val_loss: 0.0232
# Epoch 23/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0301
# Epoch 00023: val_loss did not improve from 0.02299
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0301 - val_loss: 0.0232
# Epoch 24/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0300
# Epoch 00024: val_loss did not improve from 0.02299
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0300 - val_loss: 0.0231
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0602
# Epoch 00001: val_loss improved from inf to 0.04582, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0001.ckpt
# 200/200 [==============================] - 7s 37ms/step - loss: 0.0601 - val_loss: 0.0458
# Epoch 2/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0532
# Epoch 00002: val_loss improved from 0.04582 to 0.04416, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0002.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0532 - val_loss: 0.0442
# Epoch 3/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0512
# Epoch 00003: val_loss improved from 0.04416 to 0.04239, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0512 - val_loss: 0.0424
# Epoch 4/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0495
# Epoch 00004: val_loss improved from 0.04239 to 0.04123, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0004.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0495 - val_loss: 0.0412
# Epoch 5/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0484
# Epoch 00005: val_loss improved from 0.04123 to 0.04076, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0005.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0484 - val_loss: 0.0408
# Epoch 6/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0476
# Epoch 00006: val_loss improved from 0.04076 to 0.04028, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0006.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0476 - val_loss: 0.0403
# Epoch 7/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0471
# Epoch 00007: val_loss improved from 0.04028 to 0.03995, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0007.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0471 - val_loss: 0.0400
# Epoch 8/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0467
# Epoch 00008: val_loss improved from 0.03995 to 0.03986, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0008.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0467 - val_loss: 0.0399
# Epoch 9/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0464
# Epoch 00009: val_loss improved from 0.03986 to 0.03957, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0009.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0464 - val_loss: 0.0396
# Epoch 10/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0461
# Epoch 00010: val_loss improved from 0.03957 to 0.03927, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0010.ckpt
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0461 - val_loss: 0.0393
# Epoch 11/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0458
# Epoch 00011: val_loss improved from 0.03927 to 0.03920, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0011.ckpt
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0458 - val_loss: 0.0392
# Epoch 12/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0455
# Epoch 00012: val_loss improved from 0.03920 to 0.03900, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0012.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0455 - val_loss: 0.0390
# Epoch 13/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0453
# Epoch 00013: val_loss improved from 0.03900 to 0.03890, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0013.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0453 - val_loss: 0.0389
# Epoch 14/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0450
# Epoch 00014: val_loss improved from 0.03890 to 0.03861, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0014.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0450 - val_loss: 0.0386
# Epoch 15/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0449
# Epoch 00015: val_loss improved from 0.03861 to 0.03844, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0015.ckpt
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0449 - val_loss: 0.0384
# Epoch 16/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0447
# Epoch 00016: val_loss did not improve from 0.03844
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0447 - val_loss: 0.0385
# Epoch 17/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0445
# Epoch 00017: val_loss improved from 0.03844 to 0.03831, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0017.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0445 - val_loss: 0.0383
# Epoch 18/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0444
# Epoch 00018: val_loss did not improve from 0.03831
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0444 - val_loss: 0.0385
# Epoch 19/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0443
# Epoch 00019: val_loss improved from 0.03831 to 0.03823, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X354/cp-0019.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0443 - val_loss: 0.0382
# Epoch 20/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0440
# Epoch 00020: val_loss did not improve from 0.03823
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0440 - val_loss: 0.0385
# Epoch 21/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0440
# Epoch 00021: val_loss did not improve from 0.03823
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0440 - val_loss: 0.0382
# Epoch 22/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0438
# Epoch 00022: val_loss did not improve from 0.03823
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0439 - val_loss: 0.0383
# Epoch 23/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0437
# Epoch 00023: val_loss did not improve from 0.03823
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0437 - val_loss: 0.0386
# Epoch 24/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0436
# Epoch 00024: val_loss did not improve from 0.03823
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0436 - val_loss: 0.0385
# Epoch 25/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0434
# Epoch 00025: val_loss did not improve from 0.03823
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0435 - val_loss: 0.0386
# Epoch 26/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0434
# Epoch 00026: val_loss did not improve from 0.03823
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0434 - val_loss: 0.0384
# Train for 200 steps, validate for 50 steps
# Epoch 1/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.1178
# Epoch 00001: val_loss improved from inf to 0.04915, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X357/cp-0001.ckpt
# 200/200 [==============================] - 7s 37ms/step - loss: 0.1175 - val_loss: 0.0491
# Epoch 2/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0860
# Epoch 00002: val_loss improved from 0.04915 to 0.04892, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X357/cp-0002.ckpt
# 200/200 [==============================] - 5s 23ms/step - loss: 0.0860 - val_loss: 0.0489
# Epoch 3/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0838
# Epoch 00003: val_loss improved from 0.04892 to 0.04715, saving model to drive/My Drive/Colab Notebooks/competition/training_2_X357/cp-0003.ckpt
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0838 - val_loss: 0.0472
# Epoch 4/40
# 198/200 [============================>.] - ETA: 0s - loss: 0.0820
# Epoch 00004: val_loss did not improve from 0.04715
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0819 - val_loss: 0.0476
# Epoch 5/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0803
# Epoch 00005: val_loss did not improve from 0.04715
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0803 - val_loss: 0.0478
# Epoch 6/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0786
# Epoch 00006: val_loss did not improve from 0.04715
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0786 - val_loss: 0.0476
# Epoch 7/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0767
# Epoch 00007: val_loss did not improve from 0.04715
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0766 - val_loss: 0.0488
# Epoch 8/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0753
# Epoch 00008: val_loss did not improve from 0.04715
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0753 - val_loss: 0.0473
# Epoch 9/40
# 199/200 [============================>.] - ETA: 0s - loss: 0.0745
# Epoch 00009: val_loss did not improve from 0.04715
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0745 - val_loss: 0.0472
# Epoch 10/40
# 197/200 [============================>.] - ETA: 0s - loss: 0.0740
# Epoch 00010: val_loss did not improve from 0.04715
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0740 - val_loss: 0.0476
